# %%
import streamlit as st
import pandas as pd
import joblib

# Charger modèle et liste de features
model = joblib.load("model_xgb_arrest.pkl")
features_class = joblib.load("features_class.pkl")

st.title("Prédiction d'Arrestation - Crimes à Chicago")

st.sidebar.header("Entrer les caractéristiques du crime")

hour = st.sidebar.number_input("Heure (0-23)", min_value=0, max_value=23, value=22)
dayofweek = st.sidebar.number_input("Jour de la semaine (0=lundi ... 6=dimanche)", min_value=0, max_value=6, value=5)
month = st.sidebar.number_input("Mois (1-12)", min_value=1, max_value=12, value=12)
lat = st.sidebar.number_input("Latitude", value=41.88)
lon = st.sidebar.number_input("Longitude", value=-87.63)
primary_label = st.sidebar.number_input("PrimaryType_Label", value=15)

if st.button("Prédire"):
    # Construire observation
    new_obs = pd.DataFrame({
        "Hour": [hour],
        "DayOfWeek": [dayofweek],
        "Month": [month],
        "Latitude": [lat],
        "Longitude": [lon],
        "PrimaryType_Label": [primary_label]
    })

    # Ajouter les colonnes District_... à 0 si nécessaire
    for col in features_class:
        if col not in new_obs.columns:
            new_obs[col] = 0

    new_obs = new_obs[features_class]

    proba = model.predict_proba(new_obs)[0][1]
    pred = int(proba >= 0.5)

    st.subheader("Résultat")
    st.write(f"Probabilité d'arrestation : **{proba*100:.1f}%**")
    if pred == 1:
        st.success("Prédiction : Arrestation probable")
    else:
        st.info("Prédiction : Pas d'arrestation")
# Out:
# 2025-12-09 21:02:42.816 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-09 21:02:43.912
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run c:\Users\DELL\Desktop\projet -Machine Learning\.venv\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-12-09 21:02:43.913 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-09 21:02:43.914 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-09 21:02:43.915 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-09 21:02:43.915 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-09 21:02:43.915 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-09 21:02:43.916 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-09 21:02:43.916 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-09 21:02:43.917 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-09 21:02:43.917 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-09 21:02:43.918 Session state does not function when running a script without `streamlit run`
# 2025-12-09 21:02:43.918 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-09 21:02:43.919 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-09 21:02:43.919 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-09 21:02:43.920 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-09 21:02:43.920 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-09 21:02:43.921 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-09 21:02:43.921 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-09 21:02:43.922 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-09 21:02:43.922 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-09 21:02:43.923 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-09 21:02:43.923 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-09 21:02:43.924 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-09 21:02:43.924 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-09 21:02:43.924 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-09 21:02:43.925 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-09 21:02:43.925 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-09 21:02:43.926 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-09 21:02:43.927 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-09 21:02:43.928 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-09 21:02:43.929 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-09 21:02:43.929 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-09 21:02:43.930 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-09 21:02:43.931 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-09 21:02:43.931 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-09 21:02:43.931 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-09 21:02:43.932 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-09 21:02:43.932 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-09 21:02:43.933 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-09 21:02:43.934 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-09 21:02:43.934 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-09 21:02:43.935 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-09 21:02:43.936 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-09 21:02:43.937 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-09 21:02:43.937 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-09 21:02:43.938 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-09 21:02:43.939 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-09 21:02:43.939 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-09 21:02:43.939 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-09 21:02:43.940 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-09 21:02:43.941 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-09 21:02:43.942 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-09 21:02:43.942 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-09 21:02:43.942 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-09 21:02:43.943 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
